# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Maurilio97-P/6d-pose-vision-workshop/blob/main/INDEX.ipynb)
#
# # 6D Pose Vision Workshop — Course Index
#
# ---
#
# **25 notebooks · Camera model → ArUco → Stereo → Deep Learning → Robotics Projects**
#
# > New here? Start with **[NB 00 → Welcome & Roadmap](part_0_getting_started/00_welcome_and_roadmap.ipynb)**
#
# ---
#
# ## Part 0 — Getting Started
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 00 | [Welcome & Roadmap](part_0_getting_started/00_welcome_and_roadmap.ipynb) | Course overview, what 6D pose is, how to use these notebooks |
# | 01 | [Environment Setup](part_0_getting_started/01_environment_setup.ipynb) | Python venv, pip, OpenCV, verifying your install |
#
# ---
#
# ## Part 1 — Tools
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 02 | [Jupyter Notebooks 101](part_1_tools/02_jupyter_notebooks_101.ipynb) | Cells, kernels, shortcuts, markdown, magic commands |
# | 03 | [NumPy for CV](part_1_tools/03_numpy_for_cv.ipynb) | Arrays, broadcasting, linear algebra ops used throughout the course |
#
# ---
#
# ## Part 2 — OpenCV Foundations
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 04 | [Intro to OpenCV](part_2_opencv_foundations/04_intro_to_opencv.ipynb) | imread, imshow, BGR vs RGB, basic drawing |
# | 05 | [Image Operations](part_2_opencv_foundations/05_image_operations.ipynb) | Color spaces, thresholding, morphology, contours |
#
# ---
#
# ## Part 3 — Camera Model
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 06 | [Camera Model Theory](part_3_camera_model/06_camera_model_theory.ipynb) | Pinhole model, intrinsic matrix K, projection math |
# | 07 | [Camera Calibration](part_3_camera_model/07_camera_calibration.ipynb) | Chessboard calibration, `calibrateCamera`, saving K + dist |
# | 08 | [Distortion & Undistortion](part_3_camera_model/08_distortion_undistortion.ipynb) | Radial/tangential distortion, `undistort`, optimal new K |
#
# ---
#
# ## Part 4 — Classical Pose Estimation
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 09 | [solvePnP Explained](part_4_classical_pose/09_solvePnP_explained.ipynb) | 2D–3D correspondences, PnP algorithms, rvec + tvec |
# | 10 | [Pose with Chessboard](part_4_classical_pose/10_pose_with_chessboard.ipynb) | Full pose estimation pipeline using chessboard corners |
#
# ---
#
# ## Part 5 — ArUco Markers
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 11 | [ArUco Theory](part_5_aruco/11_aruco_theory.ipynb) | Dictionary encoding, Hamming distance, corner ordering |
# | 12 | [Generate ArUco](part_5_aruco/12_generate_aruco.ipynb) | `generateImageMarker`, batch generation, print size calculator |
# | 13 | [Detect ArUco](part_5_aruco/13_detect_aruco.ipynb) | `detectMarkers`, corners/ids/rejected, failure modes |
# | 14 | [ArUco Pose Estimation](part_5_aruco/14_aruco_pose_estimation.ipynb) | `estimatePoseSingleMarkers`, tvec/rvec, `drawFrameAxes` |
# | 15 | [ArUco Robotics App](part_5_aruco/15_aruco_robotics_app.ipynb) | Full docking pipeline: detect → alignment error → P-controller |
#
# ---
#
# ## Part 6 — Stereo Vision
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 16 | [Stereo Theory](part_6_stereo_vision/16_stereo_theory.ipynb) | Disparity, depth formula Z=fB/d, epipolar geometry, Q matrix |
# | 17 | [Stereo Calibration](part_6_stereo_vision/17_stereo_calibration.ipynb) | `stereoCalibrate`, `stereoRectify`, `initUndistortRectifyMap`, depth maps |
#
# ---
#
# ## Part 7 — Deep Learning 6D Pose
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 18 | [Intro to DL for CV](part_7_deep_learning_6d_pose/18_intro_dl_for_cv.ipynb) | CNNs, training vs inference, pretrained models, GPU stack |
# | 19 | [MediaPipe Objectron](part_7_deep_learning_6d_pose/19_mediapipe_objectron.ipynb) | 3D bounding box detection on CPU, deprecated API handling |
# | 20 | [EfficientPose](part_7_deep_learning_6d_pose/20_efficientpose.ipynb) | 4-head architecture, Phi scaling, LineMOD, ADD metric |
# | 21 | [FoundationPose & FreeZe](part_7_deep_learning_6d_pose/21_foundationpose_freeze.ipynb) | Zero-shot 6D pose, two-branch feature fusion, RANSAC alignment |
# | 22 | [MegaPose + ViSP](part_7_deep_learning_6d_pose/22_megapose_visp.ipynb) | CAD model format, render-and-compare, ViSP edge tracking |
#
# ---
#
# ## Part 8 — Robotics Projects
#
# | # | Notebook | What you'll learn |
# |---|----------|------------------|
# | 23 | [Station Alignment (ArUco)](part_8_robotics_projects/23_station_alignment_aruco.ipynb) | Multi-station registry, state machine, 3-axis controller, HUD |
# | 24 | [Pallet Detection & Fork Alignment](part_8_robotics_projects/24_pallet_detection_pose.ipynb) | Euro pallet geometry, 4-axis fork controller, multi-marker averaging |
# | 25 | [Capstone Template](part_8_robotics_projects/25_capstone_template.ipynb) | Your project: method selection guide, scaffold, rubric |
#
# ---
#
# ## Quick Reference
#
# ### Key file paths
# ```
# assets/calibration/camera_calibration.npz   ← mono camera K + dist
# assets/calibration/stereo_maps.npz          ← stereo rectification maps
# assets/aruco_markers/                        ← generated marker PNGs
# assets/sample_model/                         ← example OBJ model
# ```
#
# ### Environment detection (used in every notebook)
# ```python
# import sys
# IN_COLAB = 'google.colab' in sys.modules
# ```
#
# ### ArUco API compatibility shim (NB 12–15, 23–24)
# ```python
# def get_aruco_dict(dict_id=cv2.aruco.DICT_4X4_50):
#     try:    return cv2.aruco.getPredefinedDictionary(dict_id)  # new API
#     except: return cv2.aruco.Dictionary_get(dict_id)           # old API
# ```
